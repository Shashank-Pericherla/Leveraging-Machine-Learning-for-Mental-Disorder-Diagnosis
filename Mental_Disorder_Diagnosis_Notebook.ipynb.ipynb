# %% [markdown]
# # Exploratory Data Analysis(EDA)

# %%
#importing libraries for data analysis
import pandas as pd                           #for data manipulation
import numpy as np                            #for faster computing
import matplotlib.pyplot as plt               #for data visualizations
import seaborn as sns                         #for better graphical visualizations
import warnings
warnings.filterwarnings('ignore')

# %%
#importing the dataset 
data = pd.read_csv(r'Dataset\\EEG.machinelearing_data_BRMH.csv',index_col=0)

# %%
#checking the info of the dataset 
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 945 entries, 1 to 945
# Columns: 1147 entries, sex to COH.F.gamma.r.O1.s.O2
# dtypes: float64(1144), object(3)
# memory usage: 8.3+ MB

# %%
#checking a sample of the dataset 
data.head(5)
# Out:
#     sex   age    eeg.date  education     IQ       main.disorder  \
# no.
# 1     M  57.0   2012.8.30        NaN    NaN  Addictive disorder
# 2     M  37.0    2012.9.6        6.0  120.0  Addictive disorder
# 3     M  32.0   2012.9.10       16.0  113.0  Addictive disorder
# 4     M  35.0   2012.10.8       18.0  126.0  Addictive disorder
# 5     M  36.0  2012.10.18       16.0  112.0  Addictive disorder
#
#      AB.A.delta.a.FP1  AB.A.delta.b.FP2  AB.A.delta.c.F7  AB.A.delta.d.F3  \
# no.
# 1           35.998557         21.717375        21.518280        26.825048
# 2           13.425118         11.002916        11.942516        15.272216
# 3           29.941780         27.544684        17.150159        23.608960
# 4           21.496226         21.846832        17.364316        13.833701
# 5           37.775667         33.607679        21.865556        21.771413
#
#      ...  COH.F.gamma.o.Pz.p.P4  COH.F.gamma.o.Pz.q.T6  COH.F.gamma.o.Pz.r.O1  \
# no.  ...
# ...

# %% [markdown]
# ### Descriptive Statistics

# %%
data.describe()
# Out:
#               age   education          IQ  AB.A.delta.a.FP1  AB.A.delta.b.FP2  \
# count  945.000000  930.000000  932.000000        945.000000        945.000000
# mean    30.594804   13.438710  101.580472         20.182936         21.177584
# std     11.781592    2.550461   17.022414         11.282022         12.230662
# min     18.000000    0.000000   49.000000          3.272260          3.244199
# 25%     21.730000   12.000000   91.000000         12.784872         13.019269
# 50%     26.150000   13.000000  102.000000         17.065286         17.838251
# 75%     35.450000   16.000000  114.000000         24.492760         25.654394
# max     71.880000   20.000000  145.000000         92.826192        101.515687
#
#        AB.A.delta.c.F7  AB.A.delta.d.F3  AB.A.delta.e.Fz  AB.A.delta.f.F4  \
# count       945.000000       945.000000       945.000000       945.000000
# mean         17.749553        18.901698        20.447079        19.490329
# ...

# %% [markdown]
# ### Checking for missing values

# %%
missing_values = data.isnull().sum()           #Calculates the total number of missing values in each column
missing_values[missing_values>0]               #Returns the columns with missing values
# Out:
# education        15
# IQ               13
# Unnamed: 122    945
# dtype: int64

# %% [markdown]
# There is an unecessary column present in our dataset. Along with it, education and IQ feature columns have missing values.

# %% [markdown]
# ### Handling Missing values:

# %% [markdown]
# We have to remove the uneccesary column along with the eeg date feature as there is no use with the column. Then we fill the missing values in the IQ and education columns with the mean values as these columns consist of discrete numerical values.

# %%
#dropping the uneccesary columns 
data = data.drop(['Unnamed: 122','eeg.date'],axis=1)   

#filling the missing values with the mean value of the column                  
data['IQ'] = data['IQ'].fillna(data['IQ'].mean())                          
data['education'] = data['education'].fillna(data['education'].mean())

# %%
#checking the dataset with filled values 
data.head()
# Out:
#     sex   age  education          IQ       main.disorder  AB.A.delta.a.FP1  \
# no.
# 1     M  57.0   13.43871  101.580472  Addictive disorder         35.998557
# 2     M  37.0    6.00000  120.000000  Addictive disorder         13.425118
# 3     M  32.0   16.00000  113.000000  Addictive disorder         29.941780
# 4     M  35.0   18.00000  126.000000  Addictive disorder         21.496226
# 5     M  36.0   16.00000  112.000000  Addictive disorder         37.775667
#
#      AB.A.delta.b.FP2  AB.A.delta.c.F7  AB.A.delta.d.F3  AB.A.delta.e.Fz  ...  \
# no.                                                                       ...
# 1           21.717375        21.518280        26.825048        26.611516  ...
# 2           11.002916        11.942516        15.272216        14.151570  ...
# 3           27.544684        17.150159        23.608960        27.087811  ...
# 4           21.846832        17.364316        13.833701        14.100954  ...
# ...

# %% [markdown]
# ### Checking for duplicate rows of data

# %%
data.duplicated().any()
# Out:
# False

# %% [markdown]
# This concludes that the dataset doesn't contain any duplicate data.

# %%
#Getting all the classes of  disorders in our dataset 
data['main.disorder'].unique()
# Out:
# array(['Addictive disorder', 'Trauma and stress related disorder',
#        'Mood disorder', 'Healthy control',
#        'Obsessive compulsive disorder', 'Schizophrenia',
#        'Anxiety disorder'], dtype=object)

# %% [markdown]
# There are a total of 7 classes with 6 disorder classes and one class representing normal healthy individual.

# %% [markdown]
# ### Checking for class imbalance

# %%
#Visualizing the class distribution in our dataset 
plt.figure(figsize=(10,8),dpi=100)
sns.countplot(data=data['main.disorder'])
plt.title("Distribution of the classes of disorders")
plt.xlabel("Count")
plt.ylabel("Disorders")
# Out:
# Text(0, 0.5, 'Disorders')

# %% [markdown]
# This visualization provides info that there exists class imbalance in our dataset.

# %%
disorders = data['main.disorder'].unique()           
men =  []                                                 
women = []

for i in disorders:
    men.append(len(data[(data['main.disorder'] == i) & (data['sex'] == 'M')] ))            #calculating the number of males suffering from each disorder
    women.append(len(data[(data['main.disorder'] == i) & (data['sex'] == 'F')]))           #calculating the number of females suffering from each disorder
    
#plotting a stacked bar chart which represents the distributio of disorders across both genders
plt.figure(figsize=(15,10))
plt.bar(x=disorders,height=men)
plt.bar(x=disorders,height=women,bottom= men)
plt.xticks(rotation=45)
plt.xlabel('disorders')
plt.ylabel('count')
plt.legend(['men','women'])
plt.title('Distribution of disorders across genders')
# Out:
# Text(0.5, 1.0, 'Distribution of disorders across genders')

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# The classes in our dataset are in string format and machine learning models are trained on either int or float numbers. So, we encode the classes into numbers.

# %%
from sklearn.preprocessing import OrdinalEncoder            #importing the encoder from sklearn

encoder = OrdinalEncoder()                                  #initializing an instance of the encoder  

encoder.fit(data[['sex']])                                  #fitting the encoder with our data
data['sex']= encoder.transform(data[['sex']])               #encoding the column containing sex

encoder.fit(data[['main.disorder']])
data['main.disorder']= encoder.transform(data[['main.disorder']])         #encoding the column containing disorder

# %% [markdown]
# Splitting the dataset into training features and labels.

# %%
X = data.drop(['main.disorder'],axis=1)    #dropping the disorder classes returns the features
Y = data['main.disorder']                  #getting the classes 

X.shape, Y.shape                           #checking the shape of the data
# Out:
# ((945, 1144), (945,))

# %% [markdown]
# Now to tackle the class imbalance we use sinthetic minority oversampling technique(SMOTE) to oversample the minority classes.

# %% [markdown]
# ### Oversampling minority classes:

# %% [markdown]
# For this task we are implimenting a unique method of smote called SMOTEEN which is a combination of oversampling the data and undersampling the data by removing the outliers.

# %%
from imblearn.combine import SMOTEENN                              #importing the oversampler for imblearn library 

smote = SMOTEENN(sampling_strategy='all', random_state= 42)        #initializing the oversampler with the necessary hyper parameters 
X_resampled , Y_resampled = smote.fit_resample(X,Y)                #resampling the data

X_resampled.shape, Y_resampled.shape                               #checking the shape of the resampled data
# Out:
# ((990, 1144), (990,))

# %%
Y_resampled = Y_resampled.astype(np.int64)   #changing the dtype from float32 to int64 for faster computing

# %%
#Visualizing the class distribution in our dataset after oversampling
resampled_class_counts = Y_resampled.value_counts().sort_index()

plt.figure(figsize=(8,6),dpi=100)
plt.bar(x=resampled_class_counts.index,height= resampled_class_counts.values,)
plt.title("Distribution of the classes of disorders after oversampling")
plt.xlabel("Disorders")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# As we can see, the class imbalance has been eliminated.

# %% [markdown]
# ### Feature Scaling:

# %% [markdown]
# For this task we make use Robust scaler which is a variation of standard scaler and uses inter quatile range to calculate the scaling factor. This method is more robust and immune to outliers.

# %%
from sklearn.preprocessing import RobustScaler                       #importing the scaler from sklearn

scaler = RobustScaler()                                              #initializing the scaler 
col_names = X_resampled.columns                                      #storing the column names for future use
X_resampled = scaler.fit_transform(X_resampled)                      #applying the scaler to the data
X_resampled = pd.DataFrame(X_resampled, columns=col_names)           #converting the data to dataframe

# %% [markdown]
# ### Feature Selection (using Elastic Net):

# %% [markdown]
# Let's visualize the correlation between the features.

# %% [markdown]
# The initial columns contains categorical variables whereas the later contain numerical variables. So we have to use different correlation metrics for both.

# %%
data.iloc[:,:5].corr(method='spearman')
# Out:
#                     sex       age  education        IQ  main.disorder
# sex            1.000000 -0.162669  -0.079186  0.094274      -0.303185
# age           -0.162669  1.000000   0.107804  0.069203       0.135242
# education     -0.079186  0.107804   1.000000  0.386315      -0.020604
# IQ             0.094274  0.069203   0.386315  1.000000      -0.168881
# main.disorder -0.303185  0.135242  -0.020604 -0.168881       1.000000

# %%
data.iloc[:,5:].corr(method='pearson')
# Out:
#                        AB.A.delta.a.FP1  AB.A.delta.b.FP2  AB.A.delta.c.F7  \
# AB.A.delta.a.FP1               1.000000          0.863135         0.760832
# AB.A.delta.b.FP2               0.863135          1.000000         0.691837
# AB.A.delta.c.F7                0.760832          0.691837         1.000000
# AB.A.delta.d.F3                0.780297          0.711725         0.756565
# AB.A.delta.e.Fz                0.744126          0.691396         0.685866
# ...                                 ...               ...              ...
# COH.F.gamma.p.P4.r.O1          0.048978          0.026630         0.038260
# COH.F.gamma.p.P4.s.O2          0.050825          0.040396         0.045715
# COH.F.gamma.q.T6.r.O1          0.035897          0.020107         0.022754
# COH.F.gamma.q.T6.s.O2          0.046758          0.039273         0.057955
# COH.F.gamma.r.O1.s.O2          0.061817          0.061103         0.069376
#
# ...

# %% [markdown]
# Elastic net combines the advantages of lasso and ridge regularization to handle and assign the right coefficient for each features. we can control the trade-off between the two regularization methods in elastic net.

# %%
# importing the elastic net module 
from sklearn.linear_model import ElasticNet

elastic_net = ElasticNet( alpha =0.01, l1_ratio= 0.001)                        #initializing elastic net with the appropriate l1 and l2 ratios
elastic_net.fit(X_resampled, Y_resampled)                                      #fitting the elastic net model on the data
coef_abs = np.abs(elastic_net.coef_)                                           #calculating the coefficients for each features
sorted_coef_abs = np.argsort(coef_abs)[::-1]                                   #sorting the coefficients in descending order
top_500_features = sorted_coef_abs[:500]                                       #selecting the top 500 features
top_500_feature_names = [X_resampled.columns[i] for i in top_500_features]     #creating a list of the feature names
df=[]                                                                          #creating a list to store the new top 500 features 

for j in list(top_500_feature_names):                                          #loop to append all the top 500 features in a new dataframe
   df.append(X_resampled[j])
df = pd.concat(df, axis = 1)
# Out:
# c:\Users\Shashank Pericherla\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.799e+02, tolerance: 3.522e-01
#   model = cd_fast.enet_coordinate_descent(

# %%
top_500_feature_names
# Out:
# ['sex',
#  'AB.C.alpha.q.T6',
#  'age',
#  'IQ',
#  'COH.E.highbeta.a.FP1.q.T6',
#  'COH.A.delta.b.FP2.c.F7',
#  'COH.B.theta.c.F7.d.F3',
#  'COH.C.alpha.b.FP2.g.F8',
#  'COH.C.alpha.n.P3.q.T6',
#  'COH.B.theta.e.Fz.k.C4',
#  'COH.D.beta.b.FP2.r.O1',
#  'COH.A.delta.a.FP1.h.T3',
#  'COH.A.delta.j.Cz.r.O1',
#  'COH.C.alpha.d.F3.r.O1',
#  'AB.A.delta.s.O2',
#  'COH.C.alpha.f.F4.k.C4',
#  'COH.C.alpha.l.T4.q.T6',
#  'COH.A.delta.e.Fz.j.Cz',
#  'COH.D.beta.b.FP2.s.O2',
#  'AB.E.highbeta.p.P4',
#  'AB.A.delta.h.T3',
#  'AB.C.alpha.o.Pz',
#  'COH.B.theta.c.F7.q.T6',
#  'COH.C.alpha.k.C4.s.O2',
#  'AB.F.gamma.n.P3',
#  'COH.A.delta.j.Cz.l.T4',
#  'COH.B.theta.a.FP1.e.Fz',
#  'AB.F.gamma.c.F7',
#  'COH.A.delta.g.F8.r.O1',
#  'COH.C.alpha.c.F7.r.O1',
#  'COH.A.delta.d.F3.g.F8',
#  'COH.A.delta.f.F4.i.C3',
#  'COH.B.theta.b.FP2.s.O2',
#  'COH.A.delta.k.C4.r.O1',
#  'COH.D.beta.b.FP2.h.T3',
#  'COH.B.theta.n.P3.p.P4',
#  'COH.D.beta.b.FP2.l.T4',
#  'COH.B.theta.b.FP2.n.P3',
# ...

# %% [markdown]
# ### Data Splitting:

# %%
from sklearn.model_selection import train_test_split

#splitting the data into training and testing sets in the ratio of 80:20
X_train , X_test, y_train, y_test = train_test_split(df, Y_resampled , test_size = 0.2, random_state = 0)

# %% [markdown]
# # Machine Learning:

# %% [markdown]
# ### Model Selection:

# %% [markdown]
# Since our dataset is structured and small, machine learning models are preferred over deep learning. And since we have a large number of training features, tree based models are suitable and ensemble models like gradient boosting models are preferred.

# %% [markdown]
# LightGBM model works well with large number of features and training the model is lighter, faster, and much efficient compared to other boosting models like XGBoost or CatBoost.

# %%
#importing the models
import xgboost as xgb
import lightgbm as lgm
                                  
from sklearn.model_selection import cross_val_score,RepeatedKFold                         #importing the cross validation method
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report       #importing the evaluation metrics

RepeatedKFold = RepeatedKFold(n_splits=5, n_repeats=10, random_state = 42)                #intializing an instance of the repeated K fold with the necessary hyper parameters

# %% [markdown]
# ### LightGBM

# %%
model = lgm.LGBMClassifier(device_type='gpu',       #leveraging GPU acceleration for faster training
                       n_estimators=100,            #number of trees in the forest
                       max_depth=-1,                #maximum depth of the tree
                       learning_rate=0.1,           #learning rate
                       reg_alpha=0.1,               #L1 regularization penalty to restrict the model from overfitting
                       reg_lambda=1,                #L2 regularization penalty to restrict the model from overfitting
                       n_jobs=-1,                   #number of jobs to run in parallel
                       metric='multi_logloss',      #metric to optimize
                       )

# %%
model.fit(X_train, y_train,eval_set=[(X_train,y_train),(X_test, y_test)])
# Out:
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 127317
# [LightGBM] [Info] Number of data points in the train set: 792, number of used features: 500
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 3070, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 500 dense feature groups (0.38 MB) transferred to GPU in 0.008069 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score -2.845920
# [LightGBM] [Info] Start training from score -1.637609
# [LightGBM] [Info] Start training from score -1.677349
# [LightGBM] [Info] Start training from score -6.674561
# [LightGBM] [Info] Start training from score -1.341843
# [LightGBM] [Info] Start training from score -1.830374
# [LightGBM] [Info] Start training from score -1.983214
# ...

# %% [markdown]
# Now we check the performance of our model on unseen data.

# %%
predictions = model.predict(X_test)                         
print('Accuracy Score:',accuracy_score(y_test, predictions))
report = classification_report(y_test, predictions) 
print(report)
# Out:
# Accuracy Score: 0.9646464646464646
#               precision    recall  f1-score   support
#
#          0.0       0.88      0.88      0.88         8
#          1.0       0.95      0.95      0.95        22
#          2.0       1.00      1.00      1.00        47
#          4.0       1.00      1.00      1.00        48
#          5.0       0.94      0.94      0.94        33
#          6.0       0.93      0.93      0.93        40
#
#     accuracy                           0.96       198
#    macro avg       0.95      0.95      0.95       198
# weighted avg       0.96      0.96      0.96       198

# %% [markdown]
# Great! we got an accuracy of 96.5 with great precision and recall scores.

# %%
#Visualizing the training and validation loss
lgm.plot_metric(model,figsize=(10,6))
# Out:
# <Axes: title={'center': 'Metric during training'}, xlabel='Iterations', ylabel='multi_logloss'>

# %%
#Visualizing a random tree from boosting model 
lgm.create_tree_digraph(model,orientation='vertical',tree_index=1)

# %%
#Visualizing the confusion matrix
conf_matrix = confusion_matrix(y_test, predictions)         # getting the confusion matrix

classes = ['Addictive disorder', 'Trauma and stress related disorder',
          'Mood disorder', 'Healthy control',
          'Obsessive compulsive disorder', 'Schizophrenia',
          'Anxiety disorder']

#fixing the figure size 
plt.figure(figsize=(10, 10))

# Ploting confusion matrix
plt.imshow(conf_matrix, interpolation='nearest', cmap=plt.cm.Blues)
plt.title('Confusion Matrix')
plt.colorbar()

# Adding labels
tick_marks = np.arange(len(classes))
plt.xticks(tick_marks, classes, rotation=45)
plt.yticks(tick_marks, classes)

# Adding text annotations
thresh = conf_matrix.max() / 2.
for i in range(conf_matrix.shape[0]):
    for j in range(conf_matrix.shape[1]):
        plt.text(j, i, format(conf_matrix[i, j], 'd'),
                 horizontalalignment="center",
                 color="white" if conf_matrix[i, j] > thresh else "black")

plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.tight_layout()
plt.show()

# %%
#Calculating the cross validation scores 
scores = cross_val_score(model, df, Y_resampled, cv=RepeatedKFold)
# Out:
# [LightGBM] [Warning] Unknown parameter: eval_metric
# [LightGBM] [Warning] Unknown parameter: eval_metric
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 127319
# [LightGBM] [Info] Number of data points in the train set: 792, number of used features: 500
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 3070, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 500 dense feature groups (0.38 MB) transferred to GPU in 0.008449 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score -2.824414
# [LightGBM] [Info] Start training from score -1.711717
# [LightGBM] [Info] Start training from score -1.618316
# [LightGBM] [Info] Start training from score -6.674561
# [LightGBM] [Info] Start training from score -1.371256
# [LightGBM] [Info] Start training from score -1.822531
# ...

# %%
print("Cross-validation scores:", scores)
# Out:
# Cross-validation scores: [0.8989899  0.91414141 0.93939394 0.91919192 0.91919192 0.95454545
#  0.9040404  0.92929293 0.8989899  0.91919192 0.91919192 0.92929293
#  0.94444444 0.92929293 0.94949495 0.89393939 0.92929293 0.9040404
#  0.94949495 0.94444444 0.96464646 0.87373737 0.89393939 0.93434343
#  0.94949495 0.92424242 0.93939394 0.91414141 0.94949495 0.89393939
#  0.90909091 0.94949495 0.91414141 0.89393939 0.91414141 0.8989899
#  0.92424242 0.95454545 0.93939394 0.89393939 0.94949495 0.9040404
#  0.92929293 0.92424242 0.88383838 0.90909091 0.94444444 0.91414141
#  0.93434343 0.94949495]

# %% [markdown]
# ## XGBoost

# %%
model = xgb.XGBClassifier(device = 'cuda',
                      max_depth=0,
                      eval_metric = 'mlogloss',
                      early_stopping_rounds=10,
                      learning_rate=0.1,
                      n_estimators=100,
                      reg_alpha = 0,
                      reg_lambda = 1,
                    )

# %%
model.fit(X_train, y_train,
          eval_set=[(X_train,y_train),(X_test, y_test)],
          verbose=False)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device='cuda', early_stopping_rounds=10,
#               enable_categorical=False, eval_metric='mlogloss',
#               feature_types=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=0.1, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=0,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=100,
#               n_jobs=None, num_parallel_tree=None, objective='multi:softprob', ...)

# %%
#visualizing the training process
results = model.evals_result()
plt.plot(results['validation_0']['mlogloss'], label='train')
plt.plot(results['validation_1']['mlogloss'], label='test')
plt.xlabel('Iterations')
plt.ylabel('loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

# %%
predictions = model.predict(X_test)
print('Accuracy Score:',accuracy_score(y_test, predictions))
report = classification_report(y_test, predictions) 
print(report)
# Out:
# Accuracy Score: 0.9595959595959596
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.75      0.86         8
#          1.0       1.00      0.95      0.98        22
#          2.0       0.98      1.00      0.99        47
#          4.0       1.00      1.00      1.00        48
#          5.0       0.91      0.94      0.93        33
#          6.0       0.90      0.93      0.91        40
#
#     accuracy                           0.96       198
#    macro avg       0.97      0.93      0.94       198
# weighted avg       0.96      0.96      0.96       198

# %% [markdown]
# Visualizing the confusion matrix for the results of XGBoost

# %%
conf_matrix = confusion_matrix(y_test, predictions)         # getting the confusion matrix

classes = ['Addictive disorder', 'Trauma and stress related disorder',
          'Mood disorder', 'Healthy control',
          'Obsessive compulsive disorder', 'Schizophrenia',
          'Anxiety disorder']

#fixing the figure size 
plt.figure(figsize=(10, 10))

# Ploting confusion matrix
plt.imshow(conf_matrix, interpolation='nearest', cmap=plt.cm.Blues)
plt.title('Confusion Matrix')
plt.colorbar()

# Adding labels
tick_marks = np.arange(len(classes))
plt.xticks(tick_marks, classes, rotation=45)
plt.yticks(tick_marks, classes)

# Adding text annotations
thresh = conf_matrix.max() / 2.
for i in range(conf_matrix.shape[0]):
    for j in range(conf_matrix.shape[1]):
        plt.text(j, i, format(conf_matrix[i, j], 'd'),
                 horizontalalignment="center",
                 color="white" if conf_matrix[i, j] > thresh else "black")

plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.tight_layout()
plt.show()

# %%
#visualizing a random tree in the boosting model
xgb.to_graphviz(model,num_trees=1)

# %% [markdown]
# We achieved an excellent accuracy of 96.5 and 96 with ensemble techniques like LightGBM and XGboost and leveraging cross validation to further improve the accuracy. There is still room for improvement and in near future we will be experimenting with other techniques to further improve the metrics for mental disorder diagnosis and enhance the healthcare sector.
